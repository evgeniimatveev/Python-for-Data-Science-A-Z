# %%
# 📝 Lecture Script: Exploring Your Dataset
# ==========================================
# In this script:
# - Use `len()` to explore dataset dimensions.
# - Learn about dataset structure and columns.
# - Add advanced examples for better insights.
# Let’s explore! 🚀

# ------------------------------
# 🔹 1. Import Required Libraries
# ------------------------------
import pandas as pd
import os

# Load the dataset (replace 'DemographicData.csv' with your file if needed)
file_path = 'DemographicData.csv'

if os.path.exists(file_path):
    stats = pd.read_csv(file_path)
    print("✅ Dataset successfully loaded!")
else:
    print("⚠️ File not found. Please check the path!")

# ------------------------------
# 🔹 2. Check the Number of Rows and Columns
# ------------------------------
# Total number of rows
print("\n🔍 Total Rows:", len(stats))  

# Total number of columns
print("\n🔍 Total Columns:", len(stats.columns))  

# ------------------------------
# 🔹 3. Explore Dataset Columns
# ------------------------------
# Display all column names
print("\n🔍 Columns in the dataset:")
print(stats.columns)

# Check data types of each column
print("\n🔍 Data Types:")
print(stats.dtypes)

# ------------------------------
# 🔹 4. Perform Basic Data Exploration
# ------------------------------
# View a summary of the dataset
print("\n🔍 Dataset Overview:")
print(stats.info())

# Summary statistics
print("\n🔍 Summary Statistics:")
print(stats.describe())

# ------------------------------
# 🔹 5. Advanced Analysis: Unique Values and Value Counts
# ------------------------------
# Count unique values in the "Income Group" column
print("\n🔍 Unique Income Groups:")
print(stats['Income Group'].unique())

# Count occurrences of each "Income Group"
print("\n🔍 Value Counts for Income Groups:")
print(stats['Income Group'].value_counts())

# ------------------------------
# 🔹 6. Use `len()` for Specific Filters
# ------------------------------
# Filter countries with Birth Rate > 30 and count them
high_birth_rate = stats[stats['Birth rate'] > 30]
print("\n🔍 Number of Countries with Birth Rate > 30:", len(high_birth_rate))

# ------------------------------
# 🔹 7. Display Filtered Data
# ------------------------------
# Show first few rows of filtered data
print("\n🔍 High Birth Rate Countries:")
print(high_birth_rate[['Country Name', 'Birth rate']].head())

# ------------------------------
# 🔹 8. Bonus: Identify Empty (NaN) Values
# ------------------------------
# Count total NaN values per column
print("\n🔍 Missing Values in Each Column:")
print(stats.isna().sum())

# ------------------------------
# 🔹 9. Visualization: Row and Column Dimensions
# ------------------------------
import matplotlib.pyplot as plt

# Bar chart for dataset dimensions
plt.figure(figsize=(8, 5))
plt.bar(['Rows', 'Columns'], [len(stats), len(stats.columns)], color=['skyblue', 'orange'])
plt.title('Dataset Dimensions')
plt.ylabel('Count')
plt.show()
# Out:
# ✅ Dataset successfully loaded!
#
# 🔍 Total Rows: 195
#
# 🔍 Total Columns: 5
#
# 🔍 Columns in the dataset:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')
#
# 🔍 Data Types:
# Country Name       object
# Country Code       object
# Birth rate        float64
# Internet users    float64
# Income Group       object
# dtype: object
#
# 🔍 Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB
# None
#
# 🔍 Summary Statistics:
#        Birth rate  Internet users
# ...

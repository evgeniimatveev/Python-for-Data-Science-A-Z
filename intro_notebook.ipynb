# %% [markdown]
# # 🐍 Python Programming A–Z – Intro Notebook
#
# Welcome to the **intro Jupyter notebook** for the Python Programming A–Z course.
#
# In this notebook you will:
# - Run your first Python code cell
# - Practice variables, lists and loops
# - Write a simple function
#
# If everything runs without errors, your Python + Jupyter environment is ready.

# %%
# Quick warm-up: variables, list and loop

course_name = "Python Programming A–Z"
topics = ["Basics", "Control Flow", "Functions", "Data Structures"]

print(f"Welcome to {course_name}!")
print("Main topics in this section:")

for i, topic in enumerate(topics, start=1):
    print(f"{i}. {topic}")

# %%
# Simple function demo

def greet_student(name: str) -> str:
    """Return a friendly greeting message for a student."""
    return f"Hi, {name}! Ready to practice Python today? 🐍"


greet_student("Evgenii")
